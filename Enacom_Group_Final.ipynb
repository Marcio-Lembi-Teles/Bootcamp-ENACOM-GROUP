# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcio-Lembi-Teles/Bootcamp-ENACOM-GROUP/blob/main/Enacom_Group_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size="+3">**Data: 11/03/2024**</font>
#
# <font size="+3">**Autor: MÁRCIO LEMBI TELES**</font>

# %% [markdown]
# ![ENACOM.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <font size="+2">**1º BOOTCAMP Seletivo em Ciência de Dados:**</font>
#
# <font size="+2">**O Futuro da Geração de Energia Elétrica no Brasil!**</font>

# %% [markdown]
# <font size="+2">**- METODOLOGIA UTILIZADA**</font>
# <br><br>
# Nesse projeto foi utilizado o método *CRISP-DM (Cross-Industry Standard Process for Data Mining*) sendo uma metodologia que fornece uma estrutura abrangente para a condução de projetos de análise de dados, amplamente utilizado na prática de mineração de dados e análise preditiva, na qual apresenta as seguintes etapas:

# %% [markdown]
# ![6480acb9f030976b53cf48bd_1-crisp-dm-as-etapas-da-metodologia.png](data:image/png;base64,...)

# %% [markdown]
# <font size="+2">**1. ENTENDIMENTO DO NEGÓCIO**</font>

# %% [markdown]
# OBJETIVO:
# <br><br>
# - Desenvolver um modelo de predição utilizando um conjunto de dados que detalha a geração horária de energia elétrica no Brasil, de 2000 a 2018.
# <br><br>
# - Apesar da granularidade horária dos dados, o modelo deve focar em previsões na frequência mensal.
# <br><br>
# - Você tem a liberdade de escolher como agrupar os dados para a previsão - seja por total geral, por tipo de usina, tipo de combustível, região ou estado.
# <br><br>
# - Essa escolha deve ser justificada com base na relevância e impacto esperado no resultado da previsão.
# <br><br>
# - Para a validação do modelo, utilize os dados correspondentes aos anos de 2019 e 2020.

# %% [markdown]
# <font size="+2">**2. ENTENDIMENTO DOS DADOS**</font>

# %% [markdown]
# COLETA DOS DADOS e ANÁLISE EXPLORATÓRIA:
# <br><br>
# Fonte de dados utilizada no projeto: "OPERADOR NACIONAL DO SISTEMA ELÉTRICO - ONS" dos anos de 2000 a 2020.
# <br><br>
# Geração por usina em base horária: [https://dados.ons.org.br/dataset/geracao-usina-2](https://dados.ons.org.br/dataset/geracao-usina-2)

# %%
# URL onde os arquivos CSV serão buscados diretamente do site Banco de Dados Abertos - ONS (Operador Nacional do Sistema Elétrico)

# MOTIVO de usar dessa forma: capacidade de máquina local não conseguir processar todas as informações e deixando processo muito lento.

url_2000 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2000.csv"
url_2001 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2001.csv"
url_2002 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2002.csv"
url_2003 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2003.csv"
url_2004 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2004.csv"
url_2005 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2005.csv"
url_2006 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2006.csv"
url_2007 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2007.csv"
url_2008 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2008.csv"
url_2009 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2009.csv"
url_2010 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2010.csv"
url_2011 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2011.csv"
url_2012 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2012.csv"
url_2013 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2013.csv"
url_2014 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2014.csv"
url_2015 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2015.csv"
url_2016 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2016.csv"
url_2017 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2017.csv"
url_2018 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2018.csv"
url_2019 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2019.csv"
url_2020 = "https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_2_ho/GERACAO_USINA_2020.csv"

# %%
# Instalando as bibliotecas utilizadas no projeto

# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install statsmodels

# %%
# Carregando as bibliotecas utilizadas no projeto

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Lendo os arquivos CSV e armazenando cada um deles em um dataframe em seu respectivo ano

dados_2000 = pd.read_csv(url_2000, sep=';')
dados_2001 = pd.read_csv(url_2001, sep=';')
dados_2002 = pd.read_csv(url_2002, sep=';')
dados_2003 = pd.read_csv(url_2003, sep=';')
dados_2004 = pd.read_csv(url_2004, sep=';')
dados_2005 = pd.read_csv(url_2005, sep=';')
dados_2006 = pd.read_csv(url_2006, sep=';')
dados_2007 = pd.read_csv(url_2007, sep=';')
dados_2008 = pd.read_csv(url_2008, sep=';')
dados_2009 = pd.read_csv(url_2009, sep=';')
dados_2010 = pd.read_csv(url_2010, sep=';')
dados_2011 = pd.read_csv(url_2011, sep=';')
dados_2012 = pd.read_csv(url_2012, sep=';')
dados_2013 = pd.read_csv(url_2013, sep=';')
dados_2014 = pd.read_csv(url_2014, sep=';')
dados_2015 = pd.read_csv(url_2015, sep=';')
dados_2016 = pd.read_csv(url_2016, sep=';')
dados_2017 = pd.read_csv(url_2017, sep=';')
dados_2018 = pd.read_csv(url_2018, sep=';')
dados_2019 = pd.read_csv(url_2019, sep=';')
dados_2020 = pd.read_csv(url_2020, sep=';')

# %%
# Obtendo os nomes das colunas correspondentes de cada dataframe

colunas_2000 = dados_2000.columns
colunas_2001 = dados_2001.columns
colunas_2002 = dados_2002.columns
colunas_2003 = dados_2003.columns
colunas_2004 = dados_2004.columns
colunas_2005 = dados_2005.columns
colunas_2006 = dados_2006.columns
colunas_2007 = dados_2007.columns
colunas_2008 = dados_2008.columns
colunas_2009 = dados_2009.columns
colunas_2010 = dados_2010.columns
colunas_2011 = dados_2011.columns
colunas_2012 = dados_2012.columns
colunas_2013 = dados_2013.columns
colunas_2014 = dados_2014.columns
colunas_2015 = dados_2015.columns
colunas_2016 = dados_2016.columns
colunas_2017 = dados_2017.columns
colunas_2018 = dados_2018.columns
colunas_2019 = dados_2019.columns
colunas_2020 = dados_2020.columns

# Imprimindo as colunas de cada dataframe para comparação

print("Colunas do DataFrame dados_2000:")
print(colunas_2000)

print("\nColunas do DataFrame dados_2001:")
print(colunas_2001)

print("\nColunas do DataFrame dados_2002:")
print(colunas_2002)

print("\nColunas do DataFrame dados_2003:")
print(colunas_2003)

print("\nColunas do DataFrame dados_2004:")
print(colunas_2004)

print("\nColunas do DataFrame dados_2005:")
print(colunas_2005)

print("\nColunas do DataFrame dados_2006:")
print(colunas_2006)

print("\nColunas do DataFrame dados_2007:")
print(colunas_2007)

print("\nColunas do DataFrame dados_2008:")
print(colunas_2008)

print("\nColunas do DataFrame dados_2009:")
print(colunas_2009)

print("\nColunas do DataFrame dados_2010:")
print(colunas_2010)

print("\nColunas do DataFrame dados_2011:")
print(colunas_2011)

print("\nColunas do DataFrame dados_2012:")
print(colunas_2012)

print("\nColunas do DataFrame dados_2013:")
print(colunas_2013)

print("\nColunas do DataFrame dados_2014:")
print(colunas_2014)

print("\nColunas do DataFrame dados_2015:")
print(colunas_2015)

print("\nColunas do DataFrame dados_2016:")
print(colunas_2016)

print("\nColunas do DataFrame dados_2017:")
print(colunas_2017)

print("\nColunas do DataFrame dados_2018:")
print(colunas_2018)

print("\nColunas do DataFrame dados_2019:")
print(colunas_2019)

print("\nColunas do DataFrame dados_2020:")
print(colunas_2020)
# Out:
# Colunas do DataFrame dados_2000:
# Index(['din_instante', 'id_subsistema', 'nom_subsistema', 'id_estado',
#        'nom_estado', 'cod_modalidadeoperacao', 'nom_tipousina',
#        'nom_tipocombustivel', 'nom_usina', 'ceg', 'val_geracao'],
#       dtype='object')
#
# Colunas do DataFrame dados_2001:
# Index(['din_instante', 'id_subsistema', 'nom_subsistema', 'id_estado',
#        'nom_estado', 'cod_modalidadeoperacao', 'nom_tipousina',
#        'nom_tipocombustivel', 'nom_usina', 'ceg', 'val_geracao'],
#       dtype='object')
#
# Colunas do DataFrame dados_2002:
# Index(['din_instante', 'id_subsistema', 'nom_subsistema', 'id_estado',
#        'nom_estado', 'cod_modalidadeoperacao', 'nom_tipousina',
#        'nom_tipocombustivel', 'nom_usina', 'ceg', 'val_geracao'],
#       dtype='object')
#
# Colunas do DataFrame dados_2003:
# Index(['din_instante', 'id_subsistema', 'nom_subsistema', 'id_estado',
#        'nom_estado', 'cod_modalidadeoperacao', 'nom_tipousina',
# ...

# %% [markdown]
# DICIONÁRIO DOS DADOS:
# <br><br>
# Código: din_instante<br>
# Descrição: Data de referência<br>
# Tipo de Dado: DATETIME<br>
# Formato: YYYY-MM-DD HH:MM:SS
# <br><br>
# Código: id_subsistema<br>
# Descrição: Subsistema da Usina<br>
# Tipo de Dado: TEXTO<br>
# Formato: 3 POSIÇÕES
# <br><br>
# Código: nom_subsistema<br>
# Descrição: Nome do Subsistema<br>
# Tipo de Dado: TEXTO<br>
# Formato: 20 POSIÇÕES
# <br><br>
# Código: id_estado<br>
# Descrição: Estado onde está localizado a Usina<br>
# Tipo de Dado: TEXTO<br>
# Formato: 2 POSIÇÕES
# <br><br>
# Código: nom_estado<br>
# Descrição: Nome do Estado<br>
# Tipo de Dado: TEXTO<br>
# Formato: 30 POSIÇÕES
# <br><br>
# Código: cod_modalidadeoperacao<br>
# Descrição: Modalidade de Operação da Usina<br>
#  Tipo de Dado: TEXTO<br>
#  Formato: 20 POSIÇÕES
# <br><br>
# Código: nom_tipousina<br>
# Descrição: Tipo da Usina<br>
# Tipo de Dado: TEXTO<br>
# Formato: 30 POSIÇÕES
# <br><br>
# Código: nom_tipocombustivel<br>
# Descrição: Tipo de Combustível<br>
# Tipo de Dado: TEXTO<br>
# Formato: 50 POSIÇÕES
# <br><br>
# Código: nom_usina<br>
#  Descrição: Nome da Usina<br>
#  Tipo de Dado: TEXTO<br>
#  Formato: 60 POSIÇÕES
# <br><br>
# Código: id_ons<br>
# Descrição: Identificador ONS<br>
# Tipo de Dado: TEXTO<br>
# Formato: ATÉ 32 POSIÇÕES
# <br><br>
# Código: ceg<br>
# Descrição: Código Único do Empreendimento de Geração (ANEEL)<br>
# Tipo de Dado: TEXTO<br>
# Formato: 30 POSIÇÕES
# <br><br>
# Código: val_geracao<br>
# Descrição: Geração de Energia na unidade de medida MWmed<br>
# Tipo de Dado: FLOAT<br>
# Formato: 20 POSIÇÕES

# %%
# Obtendo a quantidade de linhas e colunas de cada dataframe

linhas_2000, colunas_2000 = dados_2000.shape
linhas_2001, colunas_2001 = dados_2001.shape
linhas_2002, colunas_2002 = dados_2002.shape
linhas_2003, colunas_2003 = dados_2003.shape
linhas_2004, colunas_2004 = dados_2004.shape
linhas_2005, colunas_2005 = dados_2005.shape
linhas_2006, colunas_2006 = dados_2006.shape
linhas_2007, colunas_2007 = dados_2007.shape
linhas_2008, colunas_2008 = dados_2008.shape
linhas_2009, colunas_2009 = dados_2009.shape
linhas_2010, colunas_2010 = dados_2010.shape
linhas_2011, colunas_2011 = dados_2011.shape
linhas_2012, colunas_2012 = dados_2012.shape
linhas_2013, colunas_2013 = dados_2013.shape
linhas_2014, colunas_2014 = dados_2014.shape
linhas_2015, colunas_2015 = dados_2015.shape
linhas_2016, colunas_2016 = dados_2016.shape
linhas_2017, colunas_2017 = dados_2017.shape
linhas_2018, colunas_2018 = dados_2018.shape
linhas_2019, colunas_2019 = dados_2019.shape
linhas_2020, colunas_2020 = dados_2020.shape

# Comando para fazer impressão das informações

print(f"Os dados contêm  {linhas_2000} linhas e {colunas_2000} colunas para o ano de 2000.")
print(f"Os dados contêm {linhas_2001} linhas e {colunas_2001} colunas para o ano de 2001.")
print(f"Os dados contêm {linhas_2002} linhas e {colunas_2002} colunas para o ano de 2002.")
print(f"Os dados contêm {linhas_2003} linhas e {colunas_2003} colunas para o ano de 2003.")
print(f"Os dados contêm {linhas_2004} linhas e {colunas_2004} colunas para o ano de 2004.")
print(f"Os dados contêm {linhas_2005} linhas e {colunas_2005} colunas para o ano de 2005.")
print(f"Os dados contêm {linhas_2006} linhas e {colunas_2006} colunas para o ano de 2006.")
print(f"Os dados contêm {linhas_2007} linhas e {colunas_2007} colunas para o ano de 2007.")
print(f"Os dados contêm {linhas_2008} linhas e {colunas_2008} colunas para o ano de 2008.")
print(f"Os dados contêm {linhas_2009} linhas e {colunas_2009} colunas para o ano de 2009.")
print(f"Os dados contêm {linhas_2010} linhas e {colunas_2010} colunas para o ano de 2010.")
print(f"Os dados contêm {linhas_2011} linhas e {colunas_2011} colunas para o ano de 2011.")
print(f"Os dados contêm {linhas_2012} linhas e {colunas_2012} colunas para o ano de 2012.")
print(f"Os dados contêm {linhas_2013} linhas e {colunas_2013} colunas para o ano de 2013.")
print(f"Os dados contêm {linhas_2014} linhas e {colunas_2014} colunas para o ano de 2014.")
print(f"Os dados contêm {linhas_2015} linhas e {colunas_2015} colunas para o ano de 2015.")
print(f"Os dados contêm {linhas_2016} linhas e {colunas_2016} colunas para o ano de 2016.")
print(f"Os dados contêm {linhas_2017} linhas e {colunas_2017} colunas para o ano de 2017.")
print(f"Os dados contêm {linhas_2018} linhas e {colunas_2018} colunas para o ano de 2018.")
print(f"Os dados contêm {linhas_2019} linhas e {colunas_2019} colunas para o ano de 2019.")
print(f"Os dados contêm {linhas_2020} linhas e {colunas_2020} colunas para o ano de 2020.")
# Out:
# Os dados contêm  993556 linhas e 11 colunas para o ano de 2000.
# Os dados contêm 1054365 linhas e 11 colunas para o ano de 2001.
# Os dados contêm 1423928 linhas e 11 colunas para o ano de 2002.
# Os dados contêm 1740448 linhas e 11 colunas para o ano de 2003.
# Os dados contêm 1799984 linhas e 11 colunas para o ano de 2004.
# Os dados contêm 1762877 linhas e 11 colunas para o ano de 2005.
# Os dados contêm 1456679 linhas e 12 colunas para o ano de 2006.
# Os dados contêm 1518067 linhas e 11 colunas para o ano de 2007.
# Os dados contêm 1698598 linhas e 11 colunas para o ano de 2008.
# Os dados contêm 1806338 linhas e 11 colunas para o ano de 2009.
# Os dados contêm 2084541 linhas e 11 colunas para o ano de 2010.
# Os dados contêm 2310919 linhas e 11 colunas para o ano de 2011.
# Os dados contêm 2651207 linhas e 11 colunas para o ano de 2012.
# Os dados contêm 2964021 linhas e 11 colunas para o ano de 2013.
# Os dados contêm 3522817 linhas e 11 colunas para o ano de 2014.
# ...

# %%
# Exibindo as primeiras linhas de um dataframe para verificar se os dados foram carregados corretamente

dados_2000.head()
# Out:
#           din_instante id_subsistema nom_subsistema id_estado nom_estado  \
# 0  2000-01-01 00:00:00             N          NORTE        PA       PARA
# 1  2000-01-01 00:00:00            NE       NORDESTE        AL    ALAGOAS
# 2  2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# 3  2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# 4  2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
#
#        cod_modalidadeoperacao  nom_tipousina nom_tipocombustivel  \
# 0                      TIPO I  HIDROELÉTRICA          Hidráulica
# 1                      TIPO I  HIDROELÉTRICA          Hidráulica
# 2  Pequenas Usinas (Tipo III)  HIDROELÉTRICA          Hidráulica
# 3                      TIPO I  HIDROELÉTRICA          Hidráulica
# 4                      TIPO I  HIDROELÉTRICA          Hidráulica
#
#                                    nom_usina                    ceg  \
# ...

# %%
# Exibindo as primeiras linhas de um dataframe para verificar se os dados foram carregados corretamente

dados_2006.head()
# Out:
#           din_instante id_subsistema nom_subsistema id_estado nom_estado  \
# 0  2006-01-01 00:00:00             N          NORTE        PA       PARA
# 1  2006-01-01 00:00:00             N          NORTE        PA       PARA
# 2  2006-01-01 00:00:00            NE       NORDESTE        AL    ALAGOAS
# 3  2006-01-01 00:00:00            NE       NORDESTE        AL    ALAGOAS
# 4  2006-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
#
#   cod_modalidadeoperacao  nom_tipousina nom_tipocombustivel  \
# 0                 TIPO I  HIDROELÉTRICA          Hidráulica
# 1                 TIPO I  HIDROELÉTRICA          Hidráulica
# 2                 TIPO I  HIDROELÉTRICA          Hidráulica
# 3                 TIPO I        TÉRMICA         Óleo Diesel
# 4                 TIPO I  HIDROELÉTRICA          Hidráulica
#
#             nom_usina  id_ons                    ceg  val_geracao
# 0             Tucuruí    PATU  UHE.PH.PA.002889-4.01      4613.86
# ...

# %%
# Exibindo as primeiras linhas de um dataframe para verificar se os dados foram carregados corretamente

dados_2020.head()
# Out:
#           din_instante id_subsistema nom_subsistema id_estado nom_estado  \
# 0  2020-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 1  2020-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 2  2020-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 3  2020-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 4  2020-01-01 00:00:00             N          NORTE        AM   AMAZONAS
#
#   cod_modalidadeoperacao  nom_tipousina nom_tipocombustivel  \
# 0                 TIPO I  HIDROELÉTRICA          Hidráulica
# 1                 TIPO I        TÉRMICA                 Gás
# 2               TIPO III        TÉRMICA         Óleo Diesel
# 3               TIPO III        TÉRMICA         Óleo Diesel
# 4                 TIPO I        TÉRMICA                 Gás
#
#            nom_usina id_ons                    ceg  val_geracao
# 0            Balbina   AMBA  UHE.PH.AM.000190-2.01      143.411
# ...

# %% [markdown]
# ATENÇÂO NA BASE DE DADOS:
# <br><br>
# Observa-se que os dataframes dos anos de 2006 e 2020 apresentam uma coluna a mais em relação aos outros anos.
# <br><br>
# Nesse caso se faz necessário a investigação dessa coluna extra e seus respectivos valores para ver o quanto é relevante essa informação no conjunto de dados.
# <br><br>
# Caso necessário proceder com a exclusão da mesma ou possível acréscimo com valores nulos nos outros dataframes que não contém essa informação.

# %% [markdown]
# CONTEXTO UTILIZADO PARA ANÁLISE AO LONGO DO PROJETO:
# <br><br>
# Após análise inicial da base de dados e, tendo o objetivo apresentado no início da descrição desse notebook e usando o contexto estudado através do site https://www.ons.org.br/paginas/sobre-o-sin/o-sistema-em-numeros estarei desenvolvendo ao longo do projeto um estudo sobre a variável resposta "Geração de Energia na unidade de medida MWmed", juntamente agrupado por mês e fazendo previsão sobre o tipo de usina na qual representa a maior geração "nom_tipousina = HIDRELÉTRICA".

# %% [markdown]
# ![2024-03-07_15h26_54.png](data:image/png;base64,...)

# %% [markdown]
# Observa-se que tanto para o ano de 2006 como para o ano de 2020 houve um acréscimo da coluna no seu dataframe chamada de "id_ons" = Identificador ONS.
# <br><br>
# Devido os anteriores não conterem essa informação e, a mesma ser uma coluna de dado tipo "texto", resolvi excluí-la desses dois dataframes para facilitar a união com os demais dataframes para obter apenas um conjunto de dados para realização das respectivas análises.

# %%
# Lista de todos os DataFrames
todos_dados = [dados_2000, dados_2001, dados_2002, dados_2003, dados_2004,
               dados_2005, dados_2006, dados_2007, dados_2008, dados_2009,
               dados_2010, dados_2011, dados_2012, dados_2013, dados_2014,
               dados_2015, dados_2016, dados_2017, dados_2018, dados_2019,
               dados_2020]

# %%
# Supondo que todos_dados é uma lista de DataFrames

# Lista para armazenar as somas de todas as categorias de 'nom_tipousina' para cada DataFrame
somas_val_geracao = []

# Para cada DataFrame em todos_dados
for df in todos_dados:
    # Calcular a soma para todas as categorias de 'nom_tipousina'
    soma_total = df['val_geracao'].sum() / 1000000
    somas_val_geracao.append(soma_total)

# Obter os nomes dos DataFrames
nomes_dataframes = [f'dados_{ano}' for ano in range(2000, 2021)]

# Calcular a média mensal
media_mensal_total = [soma / 12 for soma in somas_val_geracao]

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(nomes_dataframes, somas_val_geracao, marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Quantidade Total de Geração de Energia por Ano (GWmed)')
plt.xlabel('Ano')
plt.ylabel('Soma de val_geracao (GWmed)')

# Adicionar os valores sobre os pontos
for i, valor in enumerate(somas_val_geracao):
    plt.text(nomes_dataframes[i], valor, f'{valor:.1f}', ha='center', va='bottom')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade e colocá-los na vertical
plt.xticks(rotation=90)

# Exibir o gráfico sem as linhas de grade
plt.grid(False)
plt.tight_layout()  # Ajustar o layout para evitar que os rótulos se sobreponham
plt.show()

# Criar a tabela abaixo do gráfico de linha
df_tabela_total = pd.DataFrame({'DataFrames': nomes_dataframes, 'Soma de val_geracao (GWmed)': somas_val_geracao, 'Média Mensal (GWmed)': media_mensal_total})
df_tabela_total.style.format({'Soma de val_geracao (GWmed)': '{:.2f}', 'Média Mensal (GWmed)': '{:.2f}'}).hide_index()
# Out:
# <ipython-input-15-562ee6d08545>:41: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df_tabela_total.style.format({'Soma de val_geracao (GWmed)': '{:.2f}', 'Média Mensal (GWmed)': '{:.2f}'}).hide_index()
# <style type="text/css">
# </style>
# <table id="T_fb1bc" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_fb1bc_level0_col0" class="col_heading level0 col0" >DataFrames</th>
#       <th id="T_fb1bc_level0_col1" class="col_heading level0 col1" >Soma de val_geracao (GWmed)</th>
#       <th id="T_fb1bc_level0_col2" class="col_heading level0 col2" >Média Mensal (GWmed)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fb1bc_row0_col0" class="data row0 col0" >dados_2000</td>
#       <td id="T_fb1bc_row0_col1" class="data row0 col1" >356.61</td>
#       <td id="T_fb1bc_row0_col2" class="data row0 col2" >29.72</td>
#     </tr>
#     <tr>
#       <td id="T_fb1bc_row1_col0" class="data row1 col0" >dados_2001</td>
# ...

# %%
# Supondo que todos_dados é uma lista de DataFrames

# Filtrar os dados para cada DataFrame e calcular a soma apenas para 'HIDROELÉTRICA'
somas_val_hidro = []
for df in todos_dados:
    soma_hidro = df[df['nom_tipousina'] == 'HIDROELÉTRICA']['val_geracao'].sum() / 1000000
    somas_val_hidro.append(soma_hidro)

# Obter os nomes dos DataFrames
nomes_dataframes = [f'dados_{ano}' for ano in range(2000, 2021)]

# Calcular a média mensal
media_mensal_hidro = [soma / 12 for soma in somas_val_hidro]

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
linhas = plt.plot(nomes_dataframes, somas_val_hidro, marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Quantidade Total de Geração de Energia Hidroelétrica por Ano (GWmed)')
plt.xlabel('Ano')
plt.ylabel('Soma de val_geracao (GWmed)')

# Adicionar os valores sobre as linhas formatados em bilhões
for i, valor in enumerate(somas_val_hidro):
    plt.text(i, valor, f'{valor:.1f}', ha='center', va='bottom')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade e colocá-los na vertical
plt.xticks(rotation=90)
plt.gca().set_xticklabels(nomes_dataframes)

# Exibir o gráfico
plt.tight_layout()  # Ajustar o layout para evitar que os rótulos se sobreponham
plt.show()

# Criar a tabela abaixo do gráfico de linha
df_tabela_hidro = pd.DataFrame({'DataFrames': nomes_dataframes, 'Soma de val_geracao (GWmed)': somas_val_hidro, 'Média Mensal (GWmed)': media_mensal_hidro})
df_tabela_hidro.style.format({'Soma de val_geracao (GWmed)': '{:.2f}', 'Média Mensal (GWmed)': '{:.2f}'}).hide_index()
# Out:
# <ipython-input-16-97fea9b5d0f2>:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(nomes_dataframes)
# <ipython-input-16-97fea9b5d0f2>:38: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df_tabela_hidro.style.format({'Soma de val_geracao (GWmed)': '{:.2f}', 'Média Mensal (GWmed)': '{:.2f}'}).hide_index()
# <style type="text/css">
# </style>
# <table id="T_498c3" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_498c3_level0_col0" class="col_heading level0 col0" >DataFrames</th>
#       <th id="T_498c3_level0_col1" class="col_heading level0 col1" >Soma de val_geracao (GWmed)</th>
#       <th id="T_498c3_level0_col2" class="col_heading level0 col2" >Média Mensal (GWmed)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_498c3_row0_col0" class="data row0 col0" >dados_2000</td>
#       <td id="T_498c3_row0_col1" class="data row0 col1" >335.59</td>
# ...

# %%
# Lista para armazenar os percentuais de geração de energia hidrelétrica para cada mês
percentuais_hidro = []

# Para cada DataFrame em todos_dados
for df in todos_dados:
    # Calcular a soma de val_geracao para todas as categorias de 'nom_tipousina'
    soma_total = df['val_geracao'].sum()

    # Calcular a soma de val_geracao apenas para 'HIDROELÉTRICA'
    soma_hidro = df[df['nom_tipousina'] == 'HIDROELÉTRICA']['val_geracao'].sum()

    # Calcular o percentual de geração de energia hidrelétrica em relação ao total
    percentual_hidro = (soma_hidro / soma_total) * 100

    # Adicionar o percentual à lista
    percentuais_hidro.append(percentual_hidro)

# Obter os nomes dos DataFrames
nomes_dataframes = [f'dados_{ano}' for ano in range(2000, 2021)]

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(nomes_dataframes, percentuais_hidro, marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Percentual de Geração de Energia Hidrelétrica em Relação ao Total por Ano')
plt.xlabel('Ano')
plt.ylabel('Percentual de Geração Hidrelétrica (%)')

# Adicionar os valores sobre os pontos
for i, valor in enumerate(percentuais_hidro):
    plt.text(nomes_dataframes[i], valor, f'{valor:.1f}%', ha='center', va='bottom')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade e colocá-los na vertical
plt.xticks(rotation=90)

# Exibir o gráfico
plt.grid(False)
plt.tight_layout()  # Ajustar o layout para evitar que os rótulos se sobreponham
plt.show()

# %%
# DADOS FALTANTES: consulta aos dataframes e suas respectivas colunas com dados faltantes.

# Lista de todos os DataFrames
todos_dados = [dados_2000, dados_2001, dados_2002, dados_2003, dados_2004,
               dados_2005, dados_2006, dados_2007, dados_2008, dados_2009,
               dados_2010, dados_2011, dados_2012, dados_2013, dados_2014,
               dados_2015, dados_2016, dados_2017, dados_2018, dados_2019,
               dados_2020]
# Iterando sobre todos os DataFrames
for idx, df in enumerate(todos_dados):
    # Verificar quais colunas contêm dados faltantes
    colunas_com_dados_faltantes = df.columns[df.isnull().any()]

    # Exibir os DataFrames com dados faltantes
    if len(colunas_com_dados_faltantes) > 0:
        print(f"DataFrame {idx} possui dados faltantes nas seguintes colunas:")
        print(colunas_com_dados_faltantes)
        print()  # Adiciona uma linha em branco entre os resultados
    else:
        print(f"DataFrame {idx} não possui dados faltantes.")
    print()  # Adiciona uma linha em branco extra após cada iteração
# Out:
# DataFrame 0 não possui dados faltantes.
#
# DataFrame 1 não possui dados faltantes.
#
# DataFrame 2 não possui dados faltantes.
#
# DataFrame 3 possui dados faltantes nas seguintes colunas:
# Index(['cod_modalidadeoperacao'], dtype='object')
#
#
# DataFrame 4 possui dados faltantes nas seguintes colunas:
# Index(['val_geracao'], dtype='object')
#
#
# DataFrame 5 possui dados faltantes nas seguintes colunas:
# Index(['val_geracao'], dtype='object')
#
#
# DataFrame 6 possui dados faltantes nas seguintes colunas:
# Index(['val_geracao'], dtype='object')
#
#
# DataFrame 7 não possui dados faltantes.
#
# DataFrame 8 não possui dados faltantes.
#
# DataFrame 9 não possui dados faltantes.
#
# DataFrame 10 não possui dados faltantes.
#
# DataFrame 11 não possui dados faltantes.
#
# DataFrame 12 possui dados faltantes nas seguintes colunas:
# Index(['val_geracao'], dtype='object')
#
#
# DataFrame 13 possui dados faltantes nas seguintes colunas:
# Index(['val_geracao'], dtype='object')
#
#
# ...

# %%
# Verificação dos nomes das colunas, tipo de dado e quantidade de dados por coluna.

# Lista de todos os DataFrames
todos_dados = [dados_2000, dados_2001, dados_2002, dados_2003, dados_2004,
               dados_2005, dados_2006, dados_2007, dados_2008, dados_2009,
               dados_2010, dados_2011, dados_2012, dados_2013, dados_2014,
               dados_2015, dados_2016, dados_2017, dados_2018, dados_2019,
               dados_2020]

# Lista para armazenar as informações de todos os DataFrames
informacoes_totais = []

# Iterando sobre todos os DataFrames
for df in todos_dados:
    # Obtendo a contagem de valores não nulos e o tipo de objeto em cada coluna
    info_df = pd.DataFrame({
        'Tipo de Objeto': df.dtypes,
        'Contagem de Valores Não Nulos': df.count()
    })

    # Adicionando informações do DataFrame à lista de informações totais
    informacoes_totais.append(info_df)

# Exibindo as informações das colunas para todos os DataFrames
for idx, info_df in enumerate(informacoes_totais):
    print(f"Informações do DataFrame {idx}:")
    print(info_df)
    print("\n" + "="*50 + "\n")  # Linha para separar as informações de cada DataFrame
# Out:
# Informações do DataFrame 0:
#                        Tipo de Objeto  Contagem de Valores Não Nulos
# din_instante                   object                         993556
# id_subsistema                  object                         993556
# nom_subsistema                 object                         993556
# id_estado                      object                         993556
# nom_estado                     object                         993556
# cod_modalidadeoperacao         object                         993556
# nom_tipousina                  object                         993556
# nom_tipocombustivel            object                         993556
# nom_usina                      object                         993556
# ceg                            object                         993556
# val_geracao                   float64                         993556
#
# ...
#
# Informações do DataFrame 1:
#                        Tipo de Objeto  Contagem de Valores Não Nulos
# ...

# %%
# Verificação percentual da quantidade de dados faltantes para a variável resposta que será analisada.

# Lista de todos os DataFrames
todos_dados = [dados_2000, dados_2001, dados_2002, dados_2003, dados_2004,
               dados_2005, dados_2006, dados_2007, dados_2008, dados_2009,
               dados_2010, dados_2011, dados_2012, dados_2013, dados_2014,
               dados_2015, dados_2016, dados_2017, dados_2018, dados_2019,
               dados_2020]

# Definir nomes para os DataFrames
nomes_dados = ['dados_2000', 'dados_2001', 'dados_2002', 'dados_2003', 'dados_2004',
               'dados_2005', 'dados_2006_sem_id_ons', 'dados_2007', 'dados_2008', 'dados_2009',
               'dados_2010', 'dados_2011', 'dados_2012', 'dados_2013', 'dados_2014',
               'dados_2015', 'dados_2016', 'dados_2017', 'dados_2018', 'dados_2019',
               'dados_2020_sem_id_ons']

# Iterar sobre todos os DataFrames
for nome_df, df in zip(nomes_dados, todos_dados):
    # Contagem de valores presentes e ausentes na coluna 'val_geracao'
    contagem_valores = df['val_geracao'].isnull().value_counts(normalize=True) * 100

    # Arredondar os valores para duas casas decimais
    contagem_valores = contagem_valores.round(2)

    # Criar DataFrame com os valores
    df_tabela = pd.DataFrame({
        'Presença de Valores': ['Valores Presentes', 'Valores Ausentes'],
        'Percentual': contagem_valores.tolist() + [0] if True not in contagem_valores.index else contagem_valores.tolist()
    })

    # Imprimir o título
    print(nome_df)

    # Exibir a tabela sem o índice
    print(df_tabela.to_string(index=False))
    print()  # Adicionar uma linha em branco entre as tabelas
# Out:
# dados_2000
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2001
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2002
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2003
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2004
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2005
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2006_sem_id_ons
# Presença de Valores  Percentual
#   Valores Presentes       99.99
#    Valores Ausentes        0.01
#
# dados_2007
# Presença de Valores  Percentual
#   Valores Presentes       100.0
#    Valores Ausentes         0.0
#
# dados_2008
# Presença de Valores  Percentual
# ...

# %% [markdown]
# <font size="+2">**3. PREPARAÇÃO DOS DADOS**</font>

# %%
# Lista das colunas a serem excluídas em cada dataframe
colunas_a_excluir = ['id_subsistema', 'nom_subsistema', 'id_estado', 'nom_estado', 'cod_modalidadeoperacao', 'nom_tipocombustivel', 'nom_usina', 'ceg']
colunas_adicionais = ['id_ons']

# Excluindo as colunas dos DataFrames que não serão utilizadas no projeto
dados_2000_novo = dados_2000.drop(columns=colunas_a_excluir)
dados_2001_novo = dados_2001.drop(columns=colunas_a_excluir)
dados_2002_novo = dados_2002.drop(columns=colunas_a_excluir)
dados_2003_novo = dados_2003.drop(columns=colunas_a_excluir)
dados_2004_novo = dados_2004.drop(columns=colunas_a_excluir)
dados_2005_novo = dados_2005.drop(columns=colunas_a_excluir)
dados_2006_novo = dados_2006.drop(columns=colunas_a_excluir)
dados_2007_novo = dados_2007.drop(columns=colunas_a_excluir)
dados_2008_novo = dados_2008.drop(columns=colunas_a_excluir)
dados_2009_novo = dados_2009.drop(columns=colunas_a_excluir)
dados_2010_novo = dados_2010.drop(columns=colunas_a_excluir)
dados_2011_novo = dados_2011.drop(columns=colunas_a_excluir)
dados_2012_novo = dados_2012.drop(columns=colunas_a_excluir)
dados_2013_novo = dados_2013.drop(columns=colunas_a_excluir)
dados_2014_novo = dados_2014.drop(columns=colunas_a_excluir)
dados_2015_novo = dados_2015.drop(columns=colunas_a_excluir)
dados_2016_novo = dados_2016.drop(columns=colunas_a_excluir)
dados_2017_novo = dados_2017.drop(columns=colunas_a_excluir)
dados_2018_novo = dados_2018.drop(columns=colunas_a_excluir)
dados_2019_novo = dados_2019.drop(columns=colunas_a_excluir)
dados_2020_novo = dados_2020.drop(columns=colunas_a_excluir)

dados_2006_novo = dados_2006_novo.drop(columns=colunas_adicionais)
dados_2020_novo = dados_2020_novo.drop(columns=colunas_adicionais)

# Imprimindo as cinco primeiras linhas do DataFrame dados_2000 após a exclusão das colunas
print("Dados_2000")
print(dados_2000_novo.head())
print()
print("Dados_2001")
print(dados_2001_novo.head())
print()
print("Dados_2002")
print(dados_2002_novo.head())
print()
print("Dados_2003")
print(dados_2003_novo.head())
print()
print("Dados_2004")
print(dados_2004_novo.head())
print()
print("Dados_2005")
print(dados_2005_novo.head())
print()
print("Dados_2006")
print(dados_2006_novo.head())
print()
print("Dados_2007")
print(dados_2007_novo.head())
print()
print("Dados_2008")
print(dados_2008_novo.head())
print()
print("Dados_2009")
print(dados_2009_novo.head())
print()
print("Dados_2010")
print(dados_2010_novo.head())
print()
print("Dados_2011")
print(dados_2011_novo.head())
print()
print("Dados_2012")
print(dados_2012_novo.head())
print()
print("Dados_2013")
print(dados_2013_novo.head())
print()
print("Dados_2014")
print(dados_2014_novo.head())
print()
print("Dados_2015")
print(dados_2015_novo.head())
print()
print("Dados_2016")
print(dados_2016_novo.head())
print()
print("Dados_2017")
print(dados_2017_novo.head())
print()
print("Dados_2018")
print(dados_2018_novo.head())
print()
print("Dados_2019")
print(dados_2019_novo.head())
print()
print("Dados_2020")
print(dados_2020_novo.head())
# Out:
# Dados_2000
#           din_instante  nom_tipousina  val_geracao
# 0  2000-01-01 00:00:00  HIDROELÉTRICA       2422.5
# 1  2000-01-01 00:00:00  HIDROELÉTRICA       1995.6
# 2  2000-01-01 00:00:00  HIDROELÉTRICA         13.0
# 3  2000-01-01 00:00:00  HIDROELÉTRICA        202.5
# 4  2000-01-01 00:00:00  HIDROELÉTRICA        269.8
#
# Dados_2001
#           din_instante  nom_tipousina  val_geracao
# 0  2001-01-01 00:00:00  HIDROELÉTRICA      3401.60
# 1  2001-01-01 00:00:00  HIDROELÉTRICA        27.98
# 2  2001-01-01 00:00:00  HIDROELÉTRICA      2416.40
# 3  2001-01-01 00:00:00  HIDROELÉTRICA        49.50
# 4  2001-01-01 00:00:00  HIDROELÉTRICA       101.40
#
# Dados_2002
#           din_instante  nom_tipousina  val_geracao
# 0  2002-01-01 00:00:00  HIDROELÉTRICA       3309.1
# 1  2002-01-01 00:00:00  HIDROELÉTRICA         24.0
# 2  2002-01-01 00:00:00  HIDROELÉTRICA       1271.3
# 3  2002-01-01 00:00:00  HIDROELÉTRICA       1050.8
# 4  2002-01-01 00:00:00  HIDROELÉTRICA          0.2
#
# ...

# %%
# Lista das linhas a serem excluídas em cada dataframe conforme condição

# Lista de todos os DataFrames
todos_dados_novo = [dados_2000_novo, dados_2001_novo, dados_2002_novo, dados_2003_novo, dados_2004_novo,
                    dados_2005_novo, dados_2006_novo, dados_2007_novo, dados_2008_novo, dados_2009_novo,
                    dados_2010_novo, dados_2011_novo, dados_2012_novo, dados_2013_novo, dados_2014_novo,
                    dados_2015_novo, dados_2016_novo, dados_2017_novo, dados_2018_novo, dados_2019_novo,
                    dados_2020_novo]

# Definindo os valores a serem excluídos
valores_excluir = ['TÉRMICA', 'EOLIELÉTRICA', 'FOTOVOLTAICA', 'NUCLEAR', 'BOMBEAMENTO']

# Dicionário para armazenar os DataFrames resultantes
todos_dados_novo_sem_linhas = {}

# Iterar sobre cada DataFrame na lista todos_dados_novo
for i, df in enumerate(todos_dados_novo):
    # Contagem de linhas antes da exclusão
    antes = len(df)

    # Excluindo as linhas que contenham os valores especificados na coluna 'nom_tipousina'
    df_sem_linhas = df[~df['nom_tipousina'].isin(valores_excluir)]

    # Contagem de linhas depois da exclusão
    depois = len(df_sem_linhas)

    # Calculando a diferença entre antes e depois
    diferenca = antes - depois

    # Nome do DataFrame resultante
    nome_df_sem_linhas = f'dados_{i + 2000}_novo_sem_linhas'

    # Armazenando o DataFrame resultante no dicionário
    todos_dados_novo_sem_linhas[nome_df_sem_linhas] = df_sem_linhas

    # Imprimindo os resultados
    print(f"DataFrame {i + 2000}:")
    print(f"Quantidade de linhas antes da exclusão: {antes}")
    print(f"Quantidade de linhas depois da exclusão: {depois}")
    print(f"Diferença entre antes e depois: {diferenca}")
    print()
    print(df_sem_linhas.head())
    print(f"Nome do novo DataFrame após a exclusão: {nome_df_sem_linhas}")
    print()
# Out:
# DataFrame 2000:
# Quantidade de linhas antes da exclusão: 993556
# Quantidade de linhas depois da exclusão: 808491
# Diferença entre antes e depois: 185065
#
#           din_instante  nom_tipousina  val_geracao
# 0  2000-01-01 00:00:00  HIDROELÉTRICA       2422.5
# 1  2000-01-01 00:00:00  HIDROELÉTRICA       1995.6
# 2  2000-01-01 00:00:00  HIDROELÉTRICA         13.0
# 3  2000-01-01 00:00:00  HIDROELÉTRICA        202.5
# 4  2000-01-01 00:00:00  HIDROELÉTRICA        269.8
# Nome do novo DataFrame após a exclusão: dados_2000_novo_sem_linhas
#
# DataFrame 2001:
# Quantidade de linhas antes da exclusão: 1054365
# Quantidade de linhas depois da exclusão: 842088
# Diferença entre antes e depois: 212277
#
#           din_instante  nom_tipousina  val_geracao
# 0  2001-01-01 00:00:00  HIDROELÉTRICA      3401.60
# 1  2001-01-01 00:00:00  HIDROELÉTRICA        27.98
# 2  2001-01-01 00:00:00  HIDROELÉTRICA      2416.40
# 3  2001-01-01 00:00:00  HIDROELÉTRICA        49.50
# ...

# %%
# Verificação das linhas excluídas anteriormente

for ano in range(2000, 2021):
    nome_df = f'dados_{ano}_novo_sem_linhas'
    df = todos_dados_novo_sem_linhas.get(nome_df)
    if df is not None:
        # Excluir as linhas com valor 0.000 na coluna 'val_geracao'
        todos_dados_novo_sem_linhas[nome_df] = df.loc[df['val_geracao'] != 0.000]
    else:
        print(f"DataFrame para o ano de {ano} não encontrado.")

# Verificar se as linhas foram excluídas corretamente
for ano in range(2000, 2021):
    nome_df = f'dados_{ano}_novo_sem_linhas'
    if nome_df in todos_dados_novo_sem_linhas:
        print(f"DataFrame para o ano de {ano} após a exclusão:")
        print(todos_dados_novo_sem_linhas[nome_df])
        print()
    else:
        print(f"DataFrame para o ano de {ano} não encontrado.")
# Out:
# DataFrame para o ano de 2000 após a exclusão:
#                din_instante  nom_tipousina  val_geracao
# 0       2000-01-01 00:00:00  HIDROELÉTRICA       2422.5
# 1       2000-01-01 00:00:00  HIDROELÉTRICA       1995.6
# 2       2000-01-01 00:00:00  HIDROELÉTRICA         13.0
# 3       2000-01-01 00:00:00  HIDROELÉTRICA        202.5
# 4       2000-01-01 00:00:00  HIDROELÉTRICA        269.8
# ...                     ...            ...          ...
# 993548  2000-12-31 23:00:00  HIDROELÉTRICA        108.4
# 993549  2000-12-31 23:00:00  HIDROELÉTRICA         79.1
# 993550  2000-12-31 23:00:00  HIDROELÉTRICA       1754.2
# 993551  2000-12-31 23:00:00  HIDROELÉTRICA        600.0
# 993552  2000-12-31 23:00:00  HIDROELÉTRICA        211.2
#
# [778346 rows x 3 columns]
#
# DataFrame para o ano de 2001 após a exclusão:
#                 din_instante  nom_tipousina  val_geracao
# 0        2001-01-01 00:00:00  HIDROELÉTRICA      3401.60
# ...

# %%
for ano in range(2000, 2021):
    nome_df = f'dados_{ano}_novo_sem_linhas'
    df = todos_dados_novo_sem_linhas.get(nome_df)
    if df is not None:
        valores_distintos = df['nom_tipousina'].unique()
        print(f"Valores distintos da coluna 'nom_tipousina' para o ano de {ano}:")
        print(valores_distintos)
        print()
    else:
        print(f"DataFrame para o ano de {ano} não encontrado.")
# Out:
# Valores distintos da coluna 'nom_tipousina' para o ano de 2000:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2001:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2002:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2003:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2004:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2005:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2006:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2007:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2008:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2009:
# ['HIDROELÉTRICA']
#
# Valores distintos da coluna 'nom_tipousina' para o ano de 2010:
# ['HIDROELÉTRICA']
#
# ...

# %%
# Alocando dados alterados em novos dataframes e seus respectivos anos

dados_2000_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2000_novo_sem_linhas']
dados_2001_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2001_novo_sem_linhas']
dados_2002_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2002_novo_sem_linhas']
dados_2003_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2003_novo_sem_linhas']
dados_2004_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2004_novo_sem_linhas']
dados_2005_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2005_novo_sem_linhas']
dados_2006_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2006_novo_sem_linhas']
dados_2007_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2007_novo_sem_linhas']
dados_2008_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2008_novo_sem_linhas']
dados_2009_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2009_novo_sem_linhas']
dados_2010_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2010_novo_sem_linhas']
dados_2011_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2011_novo_sem_linhas']
dados_2012_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2012_novo_sem_linhas']
dados_2013_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2013_novo_sem_linhas']
dados_2014_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2014_novo_sem_linhas']
dados_2015_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2015_novo_sem_linhas']
dados_2016_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2016_novo_sem_linhas']
dados_2017_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2017_novo_sem_linhas']
dados_2018_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2018_novo_sem_linhas']
dados_2019_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2019_novo_sem_linhas']
dados_2020_novo_sem_linhas = todos_dados_novo_sem_linhas['dados_2020_novo_sem_linhas']

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2000_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2000_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2000_novo_sem_linhas['Ano'] = dados_2000_novo_sem_linhas['din_instante'].dt.year
dados_2000_novo_sem_linhas['Mês'] = dados_2000_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2000_novo_sem_linhas['Ano-Mês'] = dados_2000_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2000_novo_sem_linhas['Mês'].astype(str)

# Imprimir as 5 primeiras e as 5 últimas linhas do DataFrame com as novas colunas
print("Primeiras 5 linhas:")
print(dados_2000_novo_sem_linhas.head())
print()
print("Últimas 5 linhas:")
print(dados_2000_novo_sem_linhas.tail())

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2000_novo_sem_linhas[['Ano', 'Mês']] = dados_2000_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2000_novo_sem_linhas['Ano'] = dados_2000_novo_sem_linhas['Ano'].astype(int)
dados_2000_novo_sem_linhas['Mês'] = dados_2000_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2000_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2000_total_mensal
dados_2000_total_mensal = pd.DataFrame(grupo_ano_mes)

# Renomear a coluna
dados_2000_total_mensal.columns = ['Total']

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2000_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
# Primeiras 5 linhas:
#   din_instante  nom_tipousina  val_geracao   Ano  Mês Ano-Mês
# 0   2000-01-01  HIDROELÉTRICA      2422.50  2000    1  2000-1
# 1   2000-01-01  HIDROELÉTRICA      1995.60  2000    1  2000-1
# 2   2000-01-01  HIDROELÉTRICA        13.00  2000    1  2000-1
# 3   2000-01-01  HIDROELÉTRICA       202.50  2000    1  2000-1
# 4   2000-01-01  HIDROELÉTRICA       269.80  2000    1  2000-1
#
# Últimas 5 linhas:
#               din_instante  nom_tipousina  val_geracao   Ano  Mês  Ano-Mês
# 993548 2000-12-31 23:00:00  HIDROELÉTRICA       108.40  2000   12  2000-12
# 993549 2000-12-31 23:00:00  HIDROELÉTRICA        79.10  2000   12  2000-12
# 993550 2000-12-31 23:00:00  HIDROELÉTRICA      1754.20  2000   12  2000-12
# 993551 2000-12-31 23:00:00  HIDROELÉTRICA       600.00  2000   12  2000-12
# 993552 2000-12-31 23:00:00  HIDROELÉTRICA       211.20  2000   12  2000-12
#               Total
# Ano-Mês
# 2000-1  27711264.85
# 2000-2  26849928.00
# 2000-3  28789383.89
# ...

# %%
# Conferindo se o valor calculado está coerente

# Calcular a soma da coluna "val_geracao" com duas casas decimais
soma_val_geracao = round(dados_2000_novo_sem_linhas['val_geracao'].sum(), 2)

# Imprimir o resultado
print("Soma da coluna 'val_geracao' com duas casas decimais:", soma_val_geracao)
# Out:
# Soma da coluna 'val_geracao' com duas casas decimais: 335591828.91

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2000_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2000_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2000_novo_sem_linhas['Ano'] = dados_2000_novo_sem_linhas['din_instante'].dt.year
dados_2000_novo_sem_linhas['Mês'] = dados_2000_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2000_novo_sem_linhas['Ano-Mês'] = dados_2000_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2000_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2000_novo_sem_linhas[['Ano', 'Mês']] = dados_2000_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2000_novo_sem_linhas['Ano'] = dados_2000_novo_sem_linhas['Ano'].astype(int)
dados_2000_novo_sem_linhas['Mês'] = dados_2000_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2000_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2000_total_mensal
dados_2000_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2000_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2000-1   27711264.85
# 1    2000-2   26849928.00
# 2    2000-3   28789383.89
# 3    2000-4   27810598.90
# 4    2000-5   28813392.00
# 5    2000-6   27376412.30
# 6    2000-7   27679250.03
# 7    2000-8   27812268.50
# 8    2000-9   27482979.38
# 9   2000-10   30034719.41
# 10  2000-11   27613932.59
# 11  2000-12   27617699.06
#
# Total: 335591828.91

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2001_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2001_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2001_novo_sem_linhas['Ano'] = dados_2001_novo_sem_linhas['din_instante'].dt.year
dados_2001_novo_sem_linhas['Mês'] = dados_2001_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2001_novo_sem_linhas['Ano-Mês'] = dados_2001_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2001_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2001_novo_sem_linhas[['Ano', 'Mês']] = dados_2001_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2001_novo_sem_linhas['Ano'] = dados_2001_novo_sem_linhas['Ano'].astype(int)
dados_2001_novo_sem_linhas['Mês'] = dados_2001_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2001_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2001_total_mensal
dados_2001_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2001_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2001-1   28962382.72
# 1    2001-2   26913947.60
# 2    2001-3   29808605.20
# 3    2001-4   28110677.32
# 4    2001-5   26629075.96
# 5    2001-6   20979293.82
# 6    2001-7   21521666.61
# 7    2001-8   21557366.20
# 8    2001-9   20601601.20
# 9   2001-10   22637673.53
# 10  2001-11   22074553.54
# 11  2001-12   22629794.84
#
# Total: 292426638.54

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2002_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2002_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2002_novo_sem_linhas['Ano'] = dados_2002_novo_sem_linhas['din_instante'].dt.year
dados_2002_novo_sem_linhas['Mês'] = dados_2002_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2002_novo_sem_linhas['Ano-Mês'] = dados_2002_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2002_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2002_novo_sem_linhas[['Ano', 'Mês']] = dados_2002_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2002_novo_sem_linhas['Ano'] = dados_2002_novo_sem_linhas['Ano'].astype(int)
dados_2002_novo_sem_linhas['Mês'] = dados_2002_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2002_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2002_total_mensal
dados_2002_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2002_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2002-1   23635930.78
# 1    2002-2   22632634.71
# 2    2002-3   27235627.69
# 3    2002-4   26537238.60
# 4    2002-5   26104956.66
# 5    2002-6   25161253.83
# 6    2002-7   26105915.97
# 7    2002-8   27187482.97
# 8    2002-9   25885799.71
# 9   2002-10   28930453.43
# 10  2002-11   27809019.62
# 11  2002-12   28228199.49
#
# Total: 315454513.46

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2003_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2003_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2003_novo_sem_linhas['Ano'] = dados_2003_novo_sem_linhas['din_instante'].dt.year
dados_2003_novo_sem_linhas['Mês'] = dados_2003_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2003_novo_sem_linhas['Ano-Mês'] = dados_2003_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2003_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2003_novo_sem_linhas[['Ano', 'Mês']] = dados_2003_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2003_novo_sem_linhas['Ano'] = dados_2003_novo_sem_linhas['Ano'].astype(int)
dados_2003_novo_sem_linhas['Mês'] = dados_2003_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2003_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2003_total_mensal
dados_2003_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2003_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2003-1   28591271.68
# 1    2003-2   27070140.96
# 2    2003-3   29006180.70
# 3    2003-4   28230909.58
# 4    2003-5   28213153.00
# 5    2003-6   26502197.70
# 6    2003-7   27434234.98
# 7    2003-8   27770091.34
# 8    2003-9   28005096.75
# 9   2003-10   29425695.90
# 10  2003-11   27940502.21
# 11  2003-12   28596015.12
#
# Total: 336785489.92

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2004_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2004_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2004_novo_sem_linhas['Ano'] = dados_2004_novo_sem_linhas['din_instante'].dt.year
dados_2004_novo_sem_linhas['Mês'] = dados_2004_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2004_novo_sem_linhas['Ano-Mês'] = dados_2004_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2004_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2004_novo_sem_linhas[['Ano', 'Mês']] = dados_2004_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2004_novo_sem_linhas['Ano'] = dados_2004_novo_sem_linhas['Ano'].astype(int)
dados_2004_novo_sem_linhas['Mês'] = dados_2004_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2004_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2004_total_mensal
dados_2004_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2004_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2004-1   28059208.90
# 1    2004-2   27148306.24
# 2    2004-3   30522118.29
# 3    2004-4   28928588.45
# 4    2004-5   29672393.02
# 5    2004-6   28346473.47
# 6    2004-7   29567497.15
# 7    2004-8   29863009.76
# 8    2004-9   29256472.14
# 9   2004-10   29799539.23
# 10  2004-11   29569343.03
# 11  2004-12   31200181.59
#
# Total: 351933131.27

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2005_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2005_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2005_novo_sem_linhas['Ano'] = dados_2005_novo_sem_linhas['din_instante'].dt.year
dados_2005_novo_sem_linhas['Mês'] = dados_2005_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2005_novo_sem_linhas['Ano-Mês'] = dados_2005_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2005_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2005_novo_sem_linhas[['Ano', 'Mês']] = dados_2005_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2005_novo_sem_linhas['Ano'] = dados_2005_novo_sem_linhas['Ano'].astype(int)
dados_2005_novo_sem_linhas['Mês'] = dados_2005_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2005_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2005_total_mensal
dados_2005_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2005_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2005-1   31747163.68
# 1    2005-2   29393794.56
# 2    2005-3   33283100.29
# 3    2005-4   31113907.81
# 4    2005-5   30490403.15
# 5    2005-6   29708969.25
# 6    2005-7   29978420.71
# 7    2005-8   30964859.57
# 8    2005-9   29940047.15
# 9   2005-10   31474686.22
# 10  2005-11   30237723.47
# 11  2005-12   31936265.39
#
# Total: 370269341.25

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2006_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2006_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2006_novo_sem_linhas['Ano'] = dados_2006_novo_sem_linhas['din_instante'].dt.year
dados_2006_novo_sem_linhas['Mês'] = dados_2006_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2006_novo_sem_linhas['Ano-Mês'] = dados_2006_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2006_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2006_novo_sem_linhas[['Ano', 'Mês']] = dados_2006_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2006_novo_sem_linhas['Ano'] = dados_2006_novo_sem_linhas['Ano'].astype(int)
dados_2006_novo_sem_linhas['Mês'] = dados_2006_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2006_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2006_total_mensal
dados_2006_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2006_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2006-1   33354777.69
# 1    2006-2   30051735.22
# 2    2006-3   33953958.51
# 3    2006-4   31438196.71
# 4    2006-5   31604886.88
# 5    2006-6   30742586.55
# 6    2006-7   31273776.08
# 7    2006-8   32385394.77
# 8    2006-9   30504688.34
# 9   2006-10   31966125.08
# 10  2006-11   32007462.87
# 11  2006-12   32927799.24
#
# Total: 382211387.94

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2007_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2007_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2007_novo_sem_linhas['Ano'] = dados_2007_novo_sem_linhas['din_instante'].dt.year
dados_2007_novo_sem_linhas['Mês'] = dados_2007_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2007_novo_sem_linhas['Ano-Mês'] = dados_2007_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2007_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2007_novo_sem_linhas[['Ano', 'Mês']] = dados_2007_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2007_novo_sem_linhas['Ano'] = dados_2007_novo_sem_linhas['Ano'].astype(int)
dados_2007_novo_sem_linhas['Mês'] = dados_2007_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2007_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2007_total_mensal
dados_2007_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2007_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2007-1   34351601.71
# 1    2007-2   31907345.03
# 2    2007-3   36912042.50
# 3    2007-4   34440193.39
# 4    2007-5   34320089.65
# 5    2007-6   32728498.23
# 6    2007-7   33723919.28
# 7    2007-8   34162861.48
# 8    2007-9   32581487.73
# 9   2007-10   34546571.97
# 10  2007-11   32681926.18
# 11  2007-12   33552735.71
#
# Total: 405909272.86

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2008_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2008_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2008_novo_sem_linhas['Ano'] = dados_2008_novo_sem_linhas['din_instante'].dt.year
dados_2008_novo_sem_linhas['Mês'] = dados_2008_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2008_novo_sem_linhas['Ano-Mês'] = dados_2008_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2008_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2008_novo_sem_linhas[['Ano', 'Mês']] = dados_2008_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2008_novo_sem_linhas['Ano'] = dados_2008_novo_sem_linhas['Ano'].astype(int)
dados_2008_novo_sem_linhas['Mês'] = dados_2008_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2008_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2008_total_mensal
dados_2008_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2008_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2008-1   32988145.84
# 1    2008-2   30861493.01
# 2    2008-3   33832745.04
# 3    2008-4   33205496.79
# 4    2008-5   33842839.77
# 5    2008-6   33278718.31
# 6    2008-7   33237580.94
# 7    2008-8   34105758.68
# 8    2008-9   32954154.82
# 9   2008-10   34893852.31
# 10  2008-11   32992075.87
# 11  2008-12   31474213.69
#
# Total: 397667075.07

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2009_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2009_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2009_novo_sem_linhas['Ano'] = dados_2009_novo_sem_linhas['din_instante'].dt.year
dados_2009_novo_sem_linhas['Mês'] = dados_2009_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2009_novo_sem_linhas['Ano-Mês'] = dados_2009_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2009_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2009_novo_sem_linhas[['Ano', 'Mês']] = dados_2009_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2009_novo_sem_linhas['Ano'] = dados_2009_novo_sem_linhas['Ano'].astype(int)
dados_2009_novo_sem_linhas['Mês'] = dados_2009_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2009_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2009_total_mensal
dados_2009_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2009_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2009-1   33432357.43
# 1    2009-2   32326080.12
# 2    2009-3   36725603.31
# 3    2009-4   33722809.09
# 4    2009-5   32879186.58
# 5    2009-6   31430618.32
# 6    2009-7   34111836.43
# 7    2009-8   35524833.99
# 8    2009-9   34820546.77
# 9   2009-10   36141215.81
# 10  2009-11   36617350.21
# 11  2009-12   36772385.93
#
# Total: 414504823.99

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2010_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2010_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2010_novo_sem_linhas['Ano'] = dados_2010_novo_sem_linhas['din_instante'].dt.year
dados_2010_novo_sem_linhas['Mês'] = dados_2010_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2010_novo_sem_linhas['Ano-Mês'] = dados_2010_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2010_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2010_novo_sem_linhas[['Ano', 'Mês']] = dados_2010_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2010_novo_sem_linhas['Ano'] = dados_2010_novo_sem_linhas['Ano'].astype(int)
dados_2010_novo_sem_linhas['Mês'] = dados_2010_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2010_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2010_total_mensal
dados_2010_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2010_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2010-1   37588123.88
# 1    2010-2   35379221.66
# 2    2010-3   39299275.57
# 3    2010-4   36035130.92
# 4    2010-5   35750921.00
# 5    2010-6   33116126.13
# 6    2010-7   35346344.00
# 7    2010-8   33904449.23
# 8    2010-9   32438445.97
# 9   2010-10   33985815.75
# 10  2010-11   33564244.21
# 11  2010-12   36397148.58
#
# Total: 422805246.90

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2011_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2011_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2011_novo_sem_linhas['Ano'] = dados_2011_novo_sem_linhas['din_instante'].dt.year
dados_2011_novo_sem_linhas['Mês'] = dados_2011_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2011_novo_sem_linhas['Ano-Mês'] = dados_2011_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2011_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2011_novo_sem_linhas[['Ano', 'Mês']] = dados_2011_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2011_novo_sem_linhas['Ano'] = dados_2011_novo_sem_linhas['Ano'].astype(int)
dados_2011_novo_sem_linhas['Mês'] = dados_2011_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2011_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2011_total_mensal
dados_2011_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2011_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2011-1   38783352.89
# 1    2011-2   36669282.94
# 2    2011-3   39244106.72
# 3    2011-4   37769820.23
# 4    2011-5   37202252.08
# 5    2011-6   35042427.06
# 6    2011-7   36725656.54
# 7    2011-8   38603496.76
# 8    2011-9   37308228.45
# 9   2011-10   37735365.82
# 10  2011-11   36600478.03
# 11  2011-12   38481887.05
#
# Total: 450166354.57

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2012_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2012_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2012_novo_sem_linhas['Ano'] = dados_2012_novo_sem_linhas['din_instante'].dt.year
dados_2012_novo_sem_linhas['Mês'] = dados_2012_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2012_novo_sem_linhas['Ano-Mês'] = dados_2012_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2012_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2012_novo_sem_linhas[['Ano', 'Mês']] = dados_2012_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2012_novo_sem_linhas['Ano'] = dados_2012_novo_sem_linhas['Ano'].astype(int)
dados_2012_novo_sem_linhas['Mês'] = dados_2012_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2012_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2012_total_mensal
dados_2012_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2012_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2012-1   39617139.91
# 1    2012-2   39313522.50
# 2    2012-3   42622804.74
# 3    2012-4   36923038.35
# 4    2012-5   36385167.08
# 5    2012-6   35444075.09
# 6    2012-7   37008439.29
# 7    2012-8   37566036.11
# 8    2012-9   34476720.70
# 9   2012-10   35276299.06
# 10  2012-11   31796853.08
# 11  2012-12   34871691.82
#
# Total: 441301787.74

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2013_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2013_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2013_novo_sem_linhas['Ano'] = dados_2013_novo_sem_linhas['din_instante'].dt.year
dados_2013_novo_sem_linhas['Mês'] = dados_2013_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2013_novo_sem_linhas['Ano-Mês'] = dados_2013_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2013_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2013_novo_sem_linhas[['Ano', 'Mês']] = dados_2013_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2013_novo_sem_linhas['Ano'] = dados_2013_novo_sem_linhas['Ano'].astype(int)
dados_2013_novo_sem_linhas['Mês'] = dados_2013_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2013_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2013_total_mensal
dados_2013_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2013_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2013-1   34425081.93
# 1    2013-2   32990449.55
# 2    2013-3   36433268.21
# 3    2013-4   34544982.49
# 4    2013-5   33386801.79
# 5    2013-6   31645194.20
# 6    2013-7   34460987.12
# 7    2013-8   35054180.12
# 8    2013-9   34373726.60
# 9   2013-10   36179397.43
# 10  2013-11   34623388.52
# 11  2013-12   35635155.94
#
# Total: 413752613.91

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2014_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2014_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2014_novo_sem_linhas['Ano'] = dados_2014_novo_sem_linhas['din_instante'].dt.year
dados_2014_novo_sem_linhas['Mês'] = dados_2014_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2014_novo_sem_linhas['Ano-Mês'] = dados_2014_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2014_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2014_novo_sem_linhas[['Ano', 'Mês']] = dados_2014_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2014_novo_sem_linhas['Ano'] = dados_2014_novo_sem_linhas['Ano'].astype(int)
dados_2014_novo_sem_linhas['Mês'] = dados_2014_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2014_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2014_total_mensal
dados_2014_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2014_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2014-1   39457508.27
# 1    2014-2   33863745.15
# 2    2014-3   35632507.92
# 3    2014-4   33438396.99
# 4    2014-5   32013792.80
# 5    2014-6   29962939.22
# 6    2014-7   31064699.00
# 7    2014-8   30195866.11
# 8    2014-9   30936322.95
# 9   2014-10   32308441.32
# 10  2014-11   31037301.66
# 11  2014-12   31622416.98
#
# Total: 391533938.36

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2015_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2015_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2015_novo_sem_linhas['Ano'] = dados_2015_novo_sem_linhas['din_instante'].dt.year
dados_2015_novo_sem_linhas['Mês'] = dados_2015_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2015_novo_sem_linhas['Ano-Mês'] = dados_2015_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2015_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2015_novo_sem_linhas[['Ano', 'Mês']] = dados_2015_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2015_novo_sem_linhas['Ano'] = dados_2015_novo_sem_linhas['Ano'].astype(int)
dados_2015_novo_sem_linhas['Mês'] = dados_2015_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2015_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2015_total_mensal
dados_2015_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2015_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2015-1   36180758.92
# 1    2015-2   31818343.41
# 2    2015-3   34640203.46
# 3    2015-4   30471585.50
# 4    2015-5   30656858.13
# 5    2015-6   28017956.96
# 6    2015-7   30045922.05
# 7    2015-8   30091666.69
# 8    2015-9   30336602.42
# 9   2015-10   33263427.53
# 10  2015-11   31887600.60
# 11  2015-12   33562169.95
#
# Total: 380973095.62

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2016_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2016_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2016_novo_sem_linhas['Ano'] = dados_2016_novo_sem_linhas['din_instante'].dt.year
dados_2016_novo_sem_linhas['Mês'] = dados_2016_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2016_novo_sem_linhas['Ano-Mês'] = dados_2016_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2016_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2016_novo_sem_linhas[['Ano', 'Mês']] = dados_2016_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2016_novo_sem_linhas['Ano'] = dados_2016_novo_sem_linhas['Ano'].astype(int)
dados_2016_novo_sem_linhas['Mês'] = dados_2016_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2016_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2016_total_mensal
dados_2016_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2016_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2016-1   35425692.30
# 1    2016-2   36206865.20
# 2    2016-3   38663992.20
# 3    2016-4   24679370.74
# 4    2016-5   34366727.96
# 5    2016-6   32285480.25
# 6    2016-7   32915589.75
# 7    2016-8   32579978.78
# 8    2016-9   30946726.04
# 9   2016-10   32206834.91
# 10  2016-11   32083386.50
# 11  2016-12   36410339.66
#
# Total: 398770984.28

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2017_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2017_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2017_novo_sem_linhas['Ano'] = dados_2017_novo_sem_linhas['din_instante'].dt.year
dados_2017_novo_sem_linhas['Mês'] = dados_2017_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2017_novo_sem_linhas['Ano-Mês'] = dados_2017_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2017_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2017_novo_sem_linhas[['Ano', 'Mês']] = dados_2017_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2017_novo_sem_linhas['Ano'] = dados_2017_novo_sem_linhas['Ano'].astype(int)
dados_2017_novo_sem_linhas['Mês'] = dados_2017_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2017_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2017_total_mensal
dados_2017_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2017_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2017-1   39694679.09
# 1    2017-2   37667837.05
# 2    2017-3   39999189.91
# 3    2017-4   33339003.08
# 4    2017-5   33303840.67
# 5    2017-6   32076425.54
# 6    2017-7   29081194.44
# 7    2017-8   28066921.54
# 8    2017-9   27872051.86
# 9   2017-10   29237131.41
# 10  2017-11   29620327.67
# 11  2017-12   34236600.28
#
# Total: 394195202.54

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2018_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2018_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2018_novo_sem_linhas['Ano'] = dados_2018_novo_sem_linhas['din_instante'].dt.year
dados_2018_novo_sem_linhas['Mês'] = dados_2018_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2018_novo_sem_linhas['Ano-Mês'] = dados_2018_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2018_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2018_novo_sem_linhas[['Ano', 'Mês']] = dados_2018_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2018_novo_sem_linhas['Ano'] = dados_2018_novo_sem_linhas['Ano'].astype(int)
dados_2018_novo_sem_linhas['Mês'] = dados_2018_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2018_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2018_total_mensal
dados_2018_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2018_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2018-1   38334574.33
# 1    2018-2   36125593.89
# 2    2018-3   41094961.77
# 3    2018-4   36488995.36
# 4    2018-5   33466222.41
# 5    2018-6   29179700.20
# 6    2018-7   28758310.32
# 7    2018-8   28956734.86
# 8    2018-9   27641604.23
# 9   2018-10   33567229.04
# 10  2018-11   35501562.15
# 11  2018-12   39289902.59
#
# Total: 408405391.16

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

# Converter a coluna 'din_instante' em datetime
dados_2019_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2019_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2019_novo_sem_linhas['Ano'] = dados_2019_novo_sem_linhas['din_instante'].dt.year
dados_2019_novo_sem_linhas['Mês'] = dados_2019_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2019_novo_sem_linhas['Ano-Mês'] = dados_2019_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2019_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2019_novo_sem_linhas[['Ano', 'Mês']] = dados_2019_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2019_novo_sem_linhas['Ano'] = dados_2019_novo_sem_linhas['Ano'].astype(int)
dados_2019_novo_sem_linhas['Mês'] = dados_2019_novo_sem_linhas['Mês'].astype(int)

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2019_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2019_total_mensal
dados_2019_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2019_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2019-1   42639562.00
# 1    2019-2   36806860.82
# 2    2019-3   39727280.95
# 3    2019-4   37990775.55
# 4    2019-5   36749564.39
# 5    2019-6   31875674.77
# 6    2019-7   30074841.39
# 7    2019-8   27992113.02
# 8    2019-9   29245572.60
# 9   2019-10   31710778.86
# 10  2019-11   31038582.21
# 11  2019-12   33890903.94
#
# Total: 409742510.51

# %%
# Criando as colunas ANO, MÊS e ANO-MÊS para melhor análise dos dados e fazendo o somatório (agrupamento) dos valores correspondentes a cada mês

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Suprimir os avisos de SettingWithCopyWarning temporariamente
pd.set_option('mode.chained_assignment', None)

# Supondo que dados_2020_novo_sem_linhas é o DataFrame que você deseja modificar

# Converter a coluna 'din_instante' em datetime
dados_2020_novo_sem_linhas['din_instante'] = pd.to_datetime(dados_2020_novo_sem_linhas['din_instante'])

# Criar as colunas 'Ano' e 'Mês'
dados_2020_novo_sem_linhas['Ano'] = dados_2020_novo_sem_linhas['din_instante'].dt.year
dados_2020_novo_sem_linhas['Mês'] = dados_2020_novo_sem_linhas['din_instante'].dt.month

# Criar a coluna 'Ano-Mês'
dados_2020_novo_sem_linhas['Ano-Mês'] = dados_2020_novo_sem_linhas['Ano'].astype(str) + '-' + dados_2020_novo_sem_linhas['Mês'].astype(str)

# Converter a coluna "Ano-Mês" em duas colunas separadas "Ano" e "Mês"
dados_2020_novo_sem_linhas[['Ano', 'Mês']] = dados_2020_novo_sem_linhas['Ano-Mês'].str.split('-', expand=True)

# Converter as colunas "Ano" e "Mês" para tipo numérico
dados_2020_novo_sem_linhas.loc[:, 'Ano'] = dados_2020_novo_sem_linhas['Ano'].astype(int)
dados_2020_novo_sem_linhas.loc[:, 'Mês'] = dados_2020_novo_sem_linhas['Mês'].astype(int)

# Restaurar o comportamento padrão dos avisos
pd.set_option('mode.chained_assignment', 'warn')

# Ordenar o DataFrame primeiro pelo ano e depois pelo mês
dados_ordenados = dados_2020_novo_sem_linhas.sort_values(by=['Ano', 'Mês'])

# Agrupar o DataFrame ordenado pela coluna "Ano-Mês" e calcular o somatório da coluna "val_geracao"
grupo_ano_mes = dados_ordenados.groupby('Ano-Mês', sort=False)['val_geracao'].sum()

# Calcular o total
total = grupo_ano_mes.sum()

# Armazenar o DataFrame agrupado no dataframe dados_2020_total_mensal
dados_2020_total_mensal = pd.DataFrame({'Ano-Mês': grupo_ano_mes.index, 'Total Mensal': grupo_ano_mes.values})

# Imprimir o DataFrame agrupado e o total com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format
print(dados_2020_total_mensal)
print("\nTotal: {:.2f}".format(total))
# Out:
#     Ano-Mês  Total Mensal
# 0    2020-1   38002834.14
# 1    2020-2   38257641.98
# 2    2020-3   40523657.36
# 3    2020-4   32258891.12
# 4    2020-5   31473563.43
# 5    2020-6   30118870.36
# 6    2020-7   32694052.88
# 7    2020-8   32195047.10
# 8    2020-9   34076338.10
# 9   2020-10   33199254.66
# 10  2020-11   29333595.60
# 11  2020-12   32543576.04
#
# Total: 404677322.77

# %%
#Concatenando os dataframes de 2000 até 2018 e soma os valores da variável resposta

# Lista de dataframes
lista_dataframes = [dados_2000_total_mensal, dados_2001_total_mensal, dados_2002_total_mensal,
                    dados_2003_total_mensal, dados_2004_total_mensal, dados_2005_total_mensal,
                    dados_2006_total_mensal, dados_2007_total_mensal, dados_2008_total_mensal,
                    dados_2009_total_mensal, dados_2010_total_mensal, dados_2011_total_mensal,
                    dados_2012_total_mensal, dados_2013_total_mensal, dados_2014_total_mensal,
                    dados_2015_total_mensal, dados_2016_total_mensal, dados_2017_total_mensal,
                    dados_2018_total_mensal]

# Concatenar os dataframes
dados_concatenados = pd.concat(lista_dataframes)

# Calcular a soma da coluna 'Total Mensal'
soma_total_mensal = dados_concatenados['Total Mensal'].sum()

print("Soma da coluna 'Total Mensal': {:.2f}".format(soma_total_mensal))
# Out:
# Soma da coluna 'Total Mensal': 7304658118.29

# %%
#Concatenando os dataframes de 2000 até 2018 e armazendo no dataframe dados_treino

# em uma lista chamada lista_dataframes
lista_dataframes = [dados_2000_total_mensal, dados_2001_total_mensal, dados_2002_total_mensal,
                    dados_2003_total_mensal, dados_2004_total_mensal, dados_2005_total_mensal,
                    dados_2006_total_mensal, dados_2007_total_mensal, dados_2008_total_mensal,
                    dados_2009_total_mensal, dados_2010_total_mensal, dados_2011_total_mensal,
                    dados_2012_total_mensal, dados_2013_total_mensal, dados_2014_total_mensal,
                    dados_2015_total_mensal, dados_2016_total_mensal, dados_2017_total_mensal,
                    dados_2018_total_mensal]

# Concatenar os dataframes da lista em um novo dataframe chamado dados_treino
dados_treino = pd.concat(lista_dataframes, ignore_index=True)

# Imprimir o dataframe dados_treino
print(dados_treino)
# Out:
#      Ano-Mês  Total Mensal
# 0     2000-1   27711264.85
# 1     2000-2   26849928.00
# 2     2000-3   28789383.89
# 3     2000-4   27810598.90
# 4     2000-5   28813392.00
# ..       ...           ...
# 223   2018-8   28956734.86
# 224   2018-9   27641604.23
# 225  2018-10   33567229.04
# 226  2018-11   35501562.15
# 227  2018-12   39289902.59
#
# [228 rows x 2 columns]

# %%
#Concatenando os dataframes de 2000 até 2018 e soma os valores da variável resposta

# Somar os valores da coluna "Total Mensal"
total_geral = dados_treino['Total Mensal'].sum()

# Imprimir o DataFrame
print(dados_treino)

# Imprimir o total geral
print("\nTotal Geral: {:.2f}".format(total_geral))
# Out:
#      Ano-Mês  Total Mensal
# 0     2000-1   27711264.85
# 1     2000-2   26849928.00
# 2     2000-3   28789383.89
# 3     2000-4   27810598.90
# 4     2000-5   28813392.00
# ..       ...           ...
# 223   2018-8   28956734.86
# 224   2018-9   27641604.23
# 225  2018-10   33567229.04
# 226  2018-11   35501562.15
# 227  2018-12   39289902.59
#
# [228 rows x 2 columns]
#
# Total Geral: 7304658118.29

# %%
#Criando gráfico de linhas para representar o comportamento da geração de energia no modo "Hidrelétrica" ao longo do tempo desde 2000 até 2018

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
for column in dados_treino.columns[1:]:
    plt.plot(dados_treino['Ano-Mês'], dados_treino[column], marker='o', linestyle='-', label=column)

# Adicionar rótulos e título ao gráfico de linha
plt.title('Total Mensal de Geração de Energia por Ano-Mês')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade
plt.xticks(rotation=90)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Criando gráfico de linha para conferir os dados do ano de 2000

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(dados_2000_total_mensal.index, dados_2000_total_mensal['Total Mensal'], marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Total Mensal de Geração de Energia em 2000')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade
plt.xticks(rotation=90)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Criando gráfico de linha para conferir os dados do ano de 2001

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(dados_2001_total_mensal.index, dados_2001_total_mensal['Total Mensal'], marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Total Mensal de Geração de Energia em 2001')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade
plt.xticks(rotation=90)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
#Concatenando os dataframes de 2019 até 2020 e soma os valores da variável resposta

# Lista de dataframes
lista_dataframes = [dados_2019_total_mensal, dados_2020_total_mensal]

# Concatenar os dataframes
dados_concatenados = pd.concat(lista_dataframes)

# Calcular a soma da coluna 'Total Mensal'
soma_total_mensal = dados_concatenados['Total Mensal'].sum()

print("Soma da coluna 'Total Mensal': {:.2f}".format(soma_total_mensal))
# Out:
# Soma da coluna 'Total Mensal': 814419833.28

# %%
#Concatenar os dataframes de 2019 e 2020 transformando em dados_teste

# em uma lista chamada lista_dataframes
lista_dataframes = [dados_2019_total_mensal, dados_2020_total_mensal]

# Concatenar os dataframes da lista em um novo dataframe chamado dados_teste
dados_teste = pd.concat(lista_dataframes, ignore_index=True)

# Imprimir o dataframe dados_teste
print(dados_teste)
# Out:
#     Ano-Mês  Total Mensal
# 0    2019-1   42639562.00
# 1    2019-2   36806860.82
# 2    2019-3   39727280.95
# 3    2019-4   37990775.55
# 4    2019-5   36749564.39
# 5    2019-6   31875674.77
# 6    2019-7   30074841.39
# 7    2019-8   27992113.02
# 8    2019-9   29245572.60
# 9   2019-10   31710778.86
# 10  2019-11   31038582.21
# 11  2019-12   33890903.94
# 12   2020-1   38002834.14
# 13   2020-2   38257641.98
# 14   2020-3   40523657.36
# 15   2020-4   32258891.12
# 16   2020-5   31473563.43
# 17   2020-6   30118870.36
# 18   2020-7   32694052.88
# 19   2020-8   32195047.10
# 20   2020-9   34076338.10
# 21  2020-10   33199254.66
# 22  2020-11   29333595.60
# 23  2020-12   32543576.04

# %%
#Somando os valoresda variável resposta do dataframe dados_teste

# Somar os valores da coluna "Total Mensal"
total_geral = dados_teste['Total Mensal'].sum()

# Imprimir o DataFrame
print(dados_teste)

# Imprimir o total geral
print("\nTotal Geral: {:.2f}".format(total_geral))
# Out:
#     Ano-Mês  Total Mensal
# 0    2019-1   42639562.00
# 1    2019-2   36806860.82
# 2    2019-3   39727280.95
# 3    2019-4   37990775.55
# 4    2019-5   36749564.39
# 5    2019-6   31875674.77
# 6    2019-7   30074841.39
# 7    2019-8   27992113.02
# 8    2019-9   29245572.60
# 9   2019-10   31710778.86
# 10  2019-11   31038582.21
# 11  2019-12   33890903.94
# 12   2020-1   38002834.14
# 13   2020-2   38257641.98
# 14   2020-3   40523657.36
# 15   2020-4   32258891.12
# 16   2020-5   31473563.43
# 17   2020-6   30118870.36
# 18   2020-7   32694052.88
# 19   2020-8   32195047.10
# 20   2020-9   34076338.10
# 21  2020-10   33199254.66
# 22  2020-11   29333595.60
# 23  2020-12   32543576.04
#
# Total Geral: 814419833.28

# %%
# Criando gráfico de linha para os dados_teste

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
for column in dados_teste.columns[1:]:
    plt.plot(dados_teste['Ano-Mês'], dados_teste[column], marker='o', linestyle='-', label=column)

# Adicionar rótulos e título ao gráfico de linha
plt.title('Total Mensal de Geração de Energia por Ano-Mês')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade
plt.xticks(rotation=90)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Criando gráfico de linha para conferir os dados do ano de 2019

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(dados_2019_total_mensal.index, dados_2019_total_mensal['Total Mensal'], marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Total Mensal de Geração de Energia em 2019')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade
plt.xticks(rotation=90)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Criando gráfico de linha para conferir os dados do ano de 2020

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(dados_2020_total_mensal.index, dados_2020_total_mensal['Total Mensal'], marker='o', linestyle='-')

# Adicionar rótulos e título ao gráfico de linha
plt.title('Total Mensal de Geração de Energia em 2020')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')

# Rotacionar os rótulos do eixo x para melhorar a legibilidade
plt.xticks(rotation=90)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
#Transformando os dataframes dados_treino e dados_teste para .CSV e exportando os mesmos para trabalhar em outro Google Colab para não sobrecarregar a memória do sistema

from google.colab import files

# Salvar dados_treino como um arquivo CSV
dados_treino.to_csv('dados_treino.csv', index=False)
# Salvar dados_teste como um arquivo CSV
dados_teste.to_csv('dados_teste.csv', index=False)

# Salvar os arquivos CSV no ambiente do Colab
files.download('dados_treino.csv')
files.download('dados_teste.csv')

# %% [markdown]
# <font size="+2">**4. MODELAGEM / ANÁLISE**</font>

# %% [markdown]
# Exclusão das colunas dos dataframes que não serão utilizadas para análise para otimização dos dados.
#
# Criar duas novas colunas para todos dataframes de mês e respectivo ano para fazer o agrupamento dos dados.
#
# Agrupar os valores com base apenas no Tipo da Usina (Hidrelétrica).

# %%
# Carregar dados de treinamento
dados_treino = pd.read_csv('/content/dados_treino.csv', parse_dates=['Ano-Mês'], index_col='Ano-Mês')

# Visualizar os primeiros registros dos dados de treinamento
print("Dados de Treinamento:")
print(dados_treino.head())

# Carregar dados de teste
dados_teste = pd.read_csv('/content/dados_teste.csv', parse_dates=['Ano-Mês'], index_col='Ano-Mês')

# Visualizar os primeiros registros dos dados de teste
print("\nDados de Teste:")
print(dados_teste.head())
# Out:
# Dados de Treinamento:
#             Total Mensal
# Ano-Mês
# 2000-01-01   27711264.85
# 2000-02-01   26849928.00
# 2000-03-01   28789383.89
# 2000-04-01   27810598.90
# 2000-05-01   28813392.00
#
# Dados de Teste:
#             Total Mensal
# Ano-Mês
# 2019-01-01   42639562.00
# 2019-02-01   36806860.82
# 2019-03-01   39727280.95
# 2019-04-01   37990775.55
# 2019-05-01   36749564.39

# %%
# Importar bibliotecas
from statsmodels.tsa.arima.model import ARIMA

#USO DO MODELO SÉRIES TEMPORAIS - ARIMA para análises de previsão

# Carregar dados de treinamento
dados_treino = pd.read_csv('dados_treino.csv', parse_dates=['Ano-Mês'], index_col='Ano-Mês')

# Visualizar os primeiros registros dos dados de treinamento
print("Dados de Treinamento:")
print(dados_treino.head())

# Carregar dados de teste
dados_teste = pd.read_csv('dados_teste.csv', parse_dates=['Ano-Mês'], index_col='Ano-Mês')

# Visualizar os primeiros registros dos dados de teste
print("\nDados de Teste:")
print(dados_teste.head())

# Plotar a série temporal de treinamento
plt.figure(figsize=(10, 6))
plt.plot(dados_treino, label='Treinamento')
plt.title('Série Temporal de Treinamento')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')
plt.legend()
plt.show()

# Ajustar o modelo ARIMA
modelo = ARIMA(dados_treino, order=(5,1,0))  # Ordem (p, d, q) do modelo ARIMA
resultado = modelo.fit()

# Fazer previsões
previsoes = resultado.predict(start=len(dados_treino), end=len(dados_treino) + len(dados_teste) - 1, typ='levels')

# Plotar previsões
plt.figure(figsize=(10, 6))
plt.plot(dados_treino, label='Treinamento')
plt.plot(dados_teste, label='Teste')
plt.plot(previsoes.index, previsoes, label='Previsões', color='red')
plt.title('Previsões com Modelo ARIMA')
plt.xlabel('Ano-Mês')
plt.ylabel('Total Mensal')
plt.legend()
plt.show()
# Out:
# Dados de Treinamento:
#             Total Mensal
# Ano-Mês
# 2000-01-01   27711264.85
# 2000-02-01   26849928.00
# 2000-03-01   28789383.89
# 2000-04-01   27810598.90
# 2000-05-01   28813392.00
#
# Dados de Teste:
#             Total Mensal
# Ano-Mês
# 2019-01-01   42639562.00
# 2019-02-01   36806860.82
# 2019-03-01   39727280.95
# 2019-04-01   37990775.55
# 2019-05-01   36749564.39
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %% [markdown]
# <font size="+2">**5. VALIDAÇÃO**</font>

# %%
#Modificando a variável "p" para 1 ajuste dos modelo

from statsmodels.tsa.arima.model import ARIMA

# Ajustar o modelo ARIMA aos dados de treinamento
modelo_arima = ARIMA(dados_treino, order=(1, 1, 1))  # Substitua p, d, q pelos valores desejados
resultado = modelo_arima.fit()

# Visualizar resumo do modelo
print(resultado.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:           Total Mensal   No. Observations:                  228
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3642.427
# Date:                Mon, 11 Mar 2024   AIC                           7290.853
# Time:                        20:09:12   BIC                           7301.128
# Sample:                    01-01-2000   HQIC                          7294.999
#                          - 12-01-2018
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4322      0.225     -1.917      0.055      -0.874       0.010
# ma.L1          0.1809      0.242      0.749      0.454      -0.292       0.654
# sigma2      4.845e+12   2.98e-14   1.62e+26      0.000    4.84e+12    4.84e+12
# ...

# %%
#Modificando a variável "p" para 100 ajuste dos modelo

from statsmodels.tsa.arima.model import ARIMA

# Ajustar o modelo ARIMA aos dados de treinamento
modelo_arima = ARIMA(dados_treino, order=(100, 1, 1))  # Substitua p, d, q pelos valores desejados
resultado = modelo_arima.fit()

# Visualizar resumo do modelo
print(resultado.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                SARIMAX Results
# ...

# %% [markdown]
# <font size="+2">**6. DEPLOY**</font>

# %%
# Momento em que se coloca em produção após análises realizadas das métricas conforme modelo, por exemplo:

# Esse é o resumo do modelo SARIMAX ajustado aos seus dados de séries temporais. Vou explicar cada parte do resumo:

# 1. Dep. Variable (Variável Dependente):
#    - Indica o nome da variável dependente, que neste caso é "Total Mensal".

# 2. No. Observations (Número de Observações):
#    - O número total de observações no conjunto de dados.

# 3. Model (Modelo):
#    - Indica o modelo utilizado para ajustar os dados. Neste caso, é ARIMA(1, 1, 1), o que significa que é um modelo ARIMA com 1 ordem de diferenciação, 1 ordem do componente autorregressivo (AR) e 1 ordem do componente de média móvel (MA).

# 4. Log Likelihood (Verossimilhança Logarítmica):
#    - É a verossimilhança logarítmica do modelo, que é uma medida da qualidade do ajuste. Quanto maior, melhor.

# 5. AIC (Critério de Informação de Akaike):
#    - O AIC é uma medida de qualidade do modelo que penaliza modelos com mais parâmetros. Quanto menor, melhor. No seu caso, o valor é 7290.853.

# 6. BIC (Critério de Informação Bayesiano):
#    - O BIC é semelhante ao AIC, mas penaliza modelos mais complexos de forma mais agressiva. Novamente, quanto menor, melhor. No seu caso, o valor é 7301.128.

# 7. Sample (Amostra):
#    - Indica o intervalo de datas coberto pelo conjunto de dados.

# 8. Covariance Type (Tipo de Covariância):
#    - O método utilizado para estimar a matriz de covariância dos parâmetros do modelo.

# 9. Coef (Coeficientes):
#    - Os coeficientes estimados para os parâmetros do modelo. No seu caso, temos o coeficiente para o componente autorregressivo (ar.L1) e o componente de média móvel (ma.L1).

# 10. sigma2 (Variância do Ruído):
#     - A variância estimada do ruído nos dados.

# 11. Ljung-Box (Q):
#     - O teste Ljung-Box é um teste de independência dos resíduos. O valor apresentado aqui é a estatística Q do teste, juntamente com o valor p associado. Um valor p baixo (geralmente <0.05) sugere que os resíduos são autocorrelacionados.

# 12. Jarque-Bera (JB):
#     - O teste de Jarque-Bera testa a normalidade dos resíduos. O valor apresentado aqui é a estatística JB do teste, juntamente com o valor p associado. Um valor p baixo (geralmente <0.05) sugere que os resíduos não seguem uma distribuição normal.

# 13. Heteroskedasticity (H):
#     - O teste de heterocedasticidade testa a igualdade da variância dos resíduos ao longo do tempo. O valor apresentado aqui é a estatística H do teste, juntamente com o valor p associado. Um valor p baixo (geralmente <0.05) sugere que os resíduos têm heterocedasticidade.

# Essas são as principais informações fornecidas no resumo do modelo SARIMAX. Cada parte fornece insights importantes sobre a qualidade do ajuste do modelo e a validade das suposições subjacentes.
